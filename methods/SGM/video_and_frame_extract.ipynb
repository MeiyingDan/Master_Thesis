# %% [markdown]
# # Read rgb video and frame_data from keyframe/data
# This notebook demonstrates how to read the rgb.mp4 video and extract frame_data.tar.gz from the keyframe/data folder.

# %%
import cv2
import tarfile

# %%
from IPython.display import Video

video_path = r' D:\FAU\Kurse\Masterarbeit\2_methods\dataset\dataset_1\keyframe_1\data\rgb.mp4'
Video(video_path, embed=True, width=800, height=600)

# %%
# Open the tar.gz file

frame_data_path = r'D:\FAU\Kurse\Masterarbeit\2_methods\dataset\dataset_1\keyframe_1\data\frame_data.tar.gz'
with tarfile.open(frame_data_path, 'r:gz') as tar:
    tar.extractall(path=r'D:\FAU\Kurse\Masterarbeit\2_methods\dataset\dataset_1\keyframe_1\data\extracted_frames')
    print("Frame data extracted successfully.")
# Out:
# Frame data extracted successfully.
